# %%
import numpy as np
import pandas as pd
import requests
import pickle
import operator
import time

# %%
def load_data():
    trend = requests.get('https://api.stocktwits.com/api/2/streams/trending.json?access_token=fdf4ddd7a52a0e54753b884627259c12ad2f13ba')
    suggest = requests.get('https://api.stocktwits.com/api/2/streams/suggested.json?access_token=fdf4ddd7a52a0e54753b884627259c12ad2f13ba')
    
    trending = trend.json()
    suggesting = suggest.json()
    
    df_trending = pd.DataFrame(trending['messages'])
    df_suggesting = pd.DataFrame(suggesting['messages'])
    
    return df_trending, df_suggesting


def load_data2():
    trend2 = requests.get('https://api.stocktwits.com/api/2/streams/trending.json?access_token=0af7726bda1f845bbe29da4c99a312e342f868c4')
    suggest2 = requests.get('https://api.stocktwits.com/api/2/streams/suggested.json?access_token=0af7726bda1f845bbe29da4c99a312e342f868c4')
    
    trending2 = trend2.json()
    suggest2 = suggest2.json()
    
    df_trending2 = pd.DataFrame(trending2['messages'])
    df_suggesting2 = pd.DataFrame(suggest2['messages'])
    
    return df_trending2, df_suggesting2

# %%
class Stock:
    def __init__(self, ticker, watch_count, total_occurances, bear, bull):
        self.ticker = ticker
        self.watch_count = watch_count
        self.total_occurances = total_occurances
        self.bear = bear
        self.bull = bull
        
    def __repr__(self):
        return ("{" + str(self.ticker) + ',' + " watch_count=" + str(self.watch_count) + ',' + " occurances=" + str(self.total_occurances) + ','  + " bear=" + str(self.bear) + ',' + " bull=" + str(self.bull) + ',' + "}")
        
    def __str__(self):
        return ("{" + str(self.ticker) + ',' + " watch_count=" + str(self.watch_count) + ',' + " occurances=" + str(self.total_occurances) + ','  + " bear=" + str(self.bear) + ',' + " bull=" + str(self.bull) + "}")
    
    def add_bear(self):
        self.bear += 1
    def add_bull(self):
        self.bull += 1
    def add_occurance(self):
        self.total_occurances += 1

# %%
# newbeverage = Stock('NBEV', 10000, 1, 0, 0)
# stock_dict = {}
# stock_set = set()
# stock_dict['NBEV'] = newbeverage
# stock_set.add('NBEV')
# print(stock_dict)
# print(stock_set)

# {'NBEV': {NBEV, watch_count=10000, occurances=1, bear=0, bull=0,}}
# {'NBEV'}

# %%
def analyze(df):
    '''insert docstring'''
    for i in range(30):
        try:
        # we have to account for the fact the message may contain no ticker
            watch_count = df['symbols'].iloc[i][0]['watchlist_count']
            tickers = df['symbols'].iloc[i]#[0]['symbol']
            bull_bear_ticker = tickers[0]['symbol']

            for j in range(len(tickers)):
                tick = tickers[j]['symbol']
                watch = tickers[j]['watchlist_count']
                if (tick not in stock_set):
                    stock_set.add(tick)
                    stock_dict[tick] = Stock(tick,watch,1,0,0)
                else:
                    stock_dict[tick].add_occurance()
                    
                # we have to account that not all messages contain a sentiment
                try:
                    sent1 = df['entities'][i]['sentiment']['basic']
                    if(sent1 == 'Bullish'):
                        stock_dict[tick].add_bull()
                    if(sent1 == 'Bearish'):
                        stock_dict[tick].add_bear()
                except:
                    pass
        except:
            pass
        
def evaluate():
    sorted_l = []
    for i in stock_set:
        sorted_l.append(stock_dict[i])
    sorted_l = sorted(sorted_l, key=operator.attrgetter('total_occurances'),reverse=True)
    for i in sorted_l:
        print(i)
    
def save_dict():
    pickle_stock = open("stock_dict.pickle", "wb")
    pickle.dump(stock_dict, pickle_stock)
    pickle_stock.close()
    
def save_set():
    pickle_stock_set = open("stock_set.pickle", "wb")
    pickle.dump(stock_set, pickle_stock_set)
    pickle_stock_set.close()

def load_dict():
    file = open('stock_dict.pickle', 'rb')
    data = pickle.load(file)
    file.close()
    return data

def load_set():
    file = open('stock_set.pickle','rb')
    data = pickle.load(file)
    file.close()
    return data

def main():
    #load data from api
    df_trending, df_suggesting = load_data()
    print('sleeping...')
    time.sleep(180)
    print('done sleeping')
    df_trending2, df_suggesting2 = load_data2()

    #load pickles from memory
#     stock_dict = load_dict()
#     stock_set = load_set()
    
    #update dictionary/set
    print('first bot')
    analyze(df_suggesting)
    analyze(df_trending)
    evaluate()
    
    print('\n')
    print('second bot')
    analyze(df_suggesting2)
    analyze(df_trending2)
    evaluate()
    
    #save the new data
    save_dict()
    save_set()
    print('\n')
    print('-'*20)
    
    time.sleep(180)

# %%
if __name__ == '__main__':
    stock_dict = {}
    stock_set = set()
    main()
# Out:
# sleeping
# done sleeping
# first bot
# {SPY, watch_count=98586, occurances=13, bear=1, bull=2}
# {TSLA, watch_count=182252, occurances=10, bear=0, bull=1}
# {SQ, watch_count=55296, occurances=6, bear=0, bull=1}
# {AMZN, watch_count=170556, occurances=4, bear=0, bull=0}
# {QQQ, watch_count=33517, occurances=3, bear=1, bull=1}
# {AMD, watch_count=144488, occurances=2, bear=0, bull=0}
# {NTNX, watch_count=11297, occurances=2, bear=0, bull=0}
# {SNAP, watch_count=84755, occurances=2, bear=0, bull=1}
# {NWL, watch_count=2462, occurances=1, bear=0, bull=0}
# {TJX, watch_count=2927, occurances=1, bear=0, bull=0}
# {PYX, watch_count=3658, occurances=1, bear=0, bull=1}
# {ZEN, watch_count=2087, occurances=1, bear=0, bull=0}
# {BTC.X, watch_count=109895, occurances=1, bear=0, bull=0}
# {INTC, watch_count=48506, occurances=1, bear=0, bull=0}
# {VIXY, watch_count=2208, occurances=1, bear=0, bull=0}
# {GOOGL, watch_count=54481, occurances=1, bear=0, bull=0}
# {TWLO, watch_count=17953, occurances=1, bear=0, bull=0}
# {WMT, watch_count=37502, occurances=1, bear=0, bull=0}
# {NZDUSD, watch_count=2862, occurances=1, bear=0, bull=0}
# {CGC, watch_count=20845, occurances=1, bear=0, bull=1}
# {MSFT, watch_count=98221, occurances=1, bear=0, bull=0}
# {EEM, watch_count=4554, occurances=1, bear=0, bull=1}
# {AUDUSD, watch_count=5426, occurances=1, bear=0, bull=0}
# {GOOG, watch_count=95023, occurances=1, bear=0, bull=0}
# {ROKU, watch_count=23452, occurances=1, bear=0, bull=0}
# {FB, watch_count=185917, occurances=1, bear=1, bull=0}
# {VIX, watch_count=13602, occurances=1, bear=0, bull=0}
# {ALGN, watch_count=4407, occurances=1, bear=0, bull=0}
# {TSM, watch_count=3656, occurances=1, bear=0, bull=0}
# {UVXY, watch_count=36067, occurances=1, bear=0, bull=0}
# {TLRY, watch_count=27653, occurances=1, bear=0, bull=1}
#
#
# second bot
# {SPY, watch_count=98586, occurances=29, bear=3, bull=2}
# {TSLA, watch_count=182252, occurances=23, bear=3, bull=1}
# {SQ, watch_count=55296, occurances=10, bear=1, bull=3}
# {AMZN, watch_count=170556, occurances=8, bear=0, bull=3}
# {QQQ, watch_count=33517, occurances=8, bear=1, bull=2}
# {SNAP, watch_count=84755, occurances=5, bear=3, bull=1}
# {AMD, watch_count=144488, occurances=3, bear=0, bull=0}
# {NTNX, watch_count=11297, occurances=3, bear=0, bull=0}
# {MSFT, watch_count=98221, occurances=3, bear=0, bull=0}
# {PYX, watch_count=3658, occurances=2, bear=0, bull=2}
# {INTC, watch_count=48506, occurances=2, bear=0, bull=0}
# {VIXY, watch_count=2208, occurances=2, bear=0, bull=0}
# {TWLO, watch_count=17953, occurances=2, bear=0, bull=1}
# {NZDUSD, watch_count=2862, occurances=2, bear=0, bull=0}
# {AUDUSD, watch_count=5426, occurances=2, bear=0, bull=0}
# {ROKU, watch_count=23452, occurances=2, bear=0, bull=0}
# {VIX, watch_count=13602, occurances=2, bear=0, bull=0}
# {TSM, watch_count=3656, occurances=2, bear=0, bull=0}
# {NWL, watch_count=2462, occurances=1, bear=0, bull=0}
# {ADBE, watch_count=11797, occurances=1, bear=0, bull=0}
# {TJX, watch_count=2927, occurances=1, bear=0, bull=0}
# {CLDC, watch_count=1711, occurances=1, bear=0, bull=1}
# {EBIX, watch_count=851, occurances=1, bear=0, bull=0}
# {ZEN, watch_count=2087, occurances=1, bear=0, bull=0}
# {AZUL, watch_count=222, occurances=1, bear=0, bull=1}
# {EARS, watch_count=13050, occurances=1, bear=0, bull=1}
# {BTC.X, watch_count=109895, occurances=1, bear=0, bull=0}
# {TVIX, watch_count=29522, occurances=1, bear=0, bull=1}
# {IWM, watch_count=11406, occurances=1, bear=0, bull=0}
# {GOOGL, watch_count=54481, occurances=1, bear=0, bull=0}
# {AAPL, watch_count=255522, occurances=1, bear=0, bull=0}
# {WMT, watch_count=37502, occurances=1, bear=0, bull=0}
# {CGC, watch_count=20845, occurances=1, bear=0, bull=1}
# {EEM, watch_count=4554, occurances=1, bear=0, bull=1}
# {QTT, watch_count=2365, occurances=1, bear=0, bull=1}
# {BZUN, watch_count=15247, occurances=1, bear=0, bull=0}
# {NFLX, watch_count=147809, occurances=1, bear=0, bull=0}
# {GOOG, watch_count=95023, occurances=1, bear=0, bull=0}
# {FB, watch_count=185917, occurances=1, bear=1, bull=0}
# {MDB, watch_count=3038, occurances=1, bear=0, bull=1}
# {ALGN, watch_count=4407, occurances=1, bear=0, bull=0}
# {UVXY, watch_count=36067, occurances=1, bear=0, bull=0}
# {TLRY, watch_count=27653, occurances=1, bear=0, bull=1}
# {SHOP, watch_count=27765, occurances=1, bear=0, bull=0}
# {ABMD, watch_count=2156, occurances=1, bear=0, bull=0}
#
#
# --------------------
